# %%
import sys
sys.path.append('..')
from src.order_book import Order, OrderBook, Side, OrderStatus

# %%
book = OrderBook()

book.add_order(Order(price=60000, size=1.0, side=Side.BID))
book.add_order(Order(price=59990, size=0.5, side=Side.BID))
book.add_order(Order(price=60010, size=1.0, side=Side.ASK))
book.add_order(Order(price=60020, size=0.5, side=Side.ASK))

# %%
print(f"Best bid: {book.best_bid}")
print(f"Best ask: {book.best_ask}")
print(f"Mid price: {book.mid_price}")
# Out:
# Best bid: 60000
# Best ask: 60010
# Mid price: 60005.0

# %%
book.add_order(Order(price=59995, size=1.0, side=Side.ASK))

# %%
print(f"Best bid: {book.best_bid}")
print(f"Best ask: {book.best_ask}")
print(f"Mid price: {book.mid_price}")
# Out:
# Best bid: 60000
# Best ask: 59995
# Mid price: 59997.5

# %%
book.match_orders()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 book.match_orders()
#
# File c:\Users\mufas\Documents\Quant Projects\quant_mm_sim\notebooks\..\src\order_book.py:119, in OrderBook.match_orders(self)
#     116 ask.fill(fill_quantity)
#     118 if self.best_bid is not None and self.best_ask is not None:
# --> 119     assert self.best_ask > self.best_bid, f"Crossed book after matching: bid {self.best_bid} >= ask {self.best_ask}"
#
# AssertionError: Crossed book after matching: bid 60000 >= ask 59995

# %%
book.__repr__
# Out:
# <method-wrapper '__repr__' of OrderBook object at 0x0000026DF1AC04C0>
